# %%
# Install Library
# !pip install quantstats
# Out:
# Requirement already satisfied: quantstats in /usr/local/lib/python3.12/dist-packages (0.0.77)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (2.0.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (3.10.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (1.16.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.2.65 in /usr/local/lib/python3.12/dist-packages (from quantstats) (0.2.66)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from quantstats) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->quantstats) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=1.5.0->quantstats) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=1.5.0->quantstats) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->quantstats) (1.17.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (4.5.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.65->quantstats) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2025.11.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.65->quantstats) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2.23)

# %%
# Import Library
import quantstats as qs
from google.colab import output
output.no_vertical_scroll()

# %%
# loading CAT data into a dataframe
qs.extend_pandas()
stock = qs.utils.download_returns("CAT")
stock
# Out:
# Date
# 1962-01-02    0.000000
# 1962-01-03    0.009740
# 1962-01-04    0.025723
# 1962-01-05    0.009405
# 1962-01-08    0.006211
#                 ...
# 2025-12-15   -0.013598
# 2025-12-16   -0.001407
# 2025-12-17   -0.045914
# 2025-12-18    0.007012
# 2025-12-19    0.018362
# Name: Close, Length: 16101, dtype: float64

# %%
qs.stats.sharpe(stock)
# Out:
# np.float64(0.5253430141061847)

# %%
qs.stats.monthly_returns(stock)
# Out:
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 1962  0.071447 -0.015243  0.012385 -0.125859 -0.031690 -0.072728  0.003801
# 1963  0.036877 -0.090909  0.042857  0.028806  0.191275 -0.028169  0.012548
# 1964  0.097494  0.035799  0.133642 -0.018018  0.031250  0.060606  0.057604
# 1965 -0.008995  0.089229 -0.079096  0.129716 -0.032786 -0.028248 -0.035021
# 1966 -0.004178 -0.073604  0.021917 -0.104092  0.030120 -0.029239 -0.098641
# ...        ...       ...       ...       ...       ...       ...       ...
# 2021  0.009849  0.180705  0.074069 -0.011769  0.056859 -0.097271 -0.044895
# 2022 -0.020325 -0.069359  0.187867 -0.050581  0.025221 -0.171832  0.116753
# 2023  0.058162 -0.050497 -0.044709 -0.038683 -0.059644  0.195869  0.083045
# 2024  0.020399  0.112051  0.097227 -0.083619  0.011806 -0.016011  0.043560
# 2025  0.027681 -0.074009 -0.041140 -0.057735  0.125328  0.115450  0.132440
#
#            AUG       SEP       OCT       NOV       DEC       EOY
# 1962  0.106299 -0.103204  0.051649  0.098858  0.034603 -0.001728
# 1963  0.034582 -0.036212  0.082547  0.013441  0.018567  0.320968
# 1964 -0.021739  0.051851  0.069141  0.112583 -0.017858  0.759744
# 1965  0.063636  0.065526  0.064547  0.073233 -0.063530  0.235049
# 1966 -0.030303 -0.048611  0.030894  0.057142 -0.054054 -0.275957
# ...        ...       ...       ...       ...       ...       ...
# 2021  0.019927 -0.089629  0.068586 -0.052252  0.069253  0.159537
# 2022 -0.068298 -0.111688  0.328062  0.092165  0.013324  0.185988
# 2023  0.060188 -0.028919 -0.167699  0.109135  0.179284  0.259488
# 2024  0.028596  0.098343 -0.034691  0.079506 -0.106744  0.246586
# 2025 -0.043331  0.138674  0.213284 -0.002598  0.000799  0.612420
#
# [64 rows x 13 columns]

# %%
qs.stats.max_drawdown(stock)
# Out:
# -0.7342865886369214

# %%
[f for f in dir(qs.stats) if f[0] != '_']
# Out:
# ['adjusted_sortino',
#  'autocorr_penalty',
#  'avg_loss',
#  'avg_return',
#  'avg_win',
#  'best',
#  'cagr',
#  'calmar',
#  'common_sense_ratio',
#  'comp',
#  'compare',
#  'compsum',
#  'conditional_value_at_risk',
#  'consecutive_losses',
#  'consecutive_wins',
#  'cpc_index',
#  'cvar',
#  'distribution',
#  'drawdown_details',
#  'expected_return',
#  'expected_shortfall',
#  'exposure',
#  'gain_to_pain_ratio',
#  'geometric_mean',
#  'ghpr',
#  'greeks',
#  'implied_volatility',
#  'information_ratio',
#  'kelly_criterion',
#  'kurtosis',
#  'max_drawdown',
#  'monthly_returns',
#  'omega',
#  'outlier_loss_ratio',
#  'outlier_win_ratio',
#  'outliers',
#  'payoff_ratio',
#  'pct_rank',
#  'probabilistic_adjusted_sortino_ratio',
#  'probabilistic_ratio',
#  'probabilistic_sharpe_ratio',
#  'probabilistic_sortino_ratio',
#  'profit_factor',
#  'profit_ratio',
#  'r2',
#  'r_squared',
#  'rar',
#  'recovery_factor',
#  'remove_outliers',
#  'risk_of_ruin',
#  'risk_return_ratio',
#  'rolling_greeks',
#  'rolling_sharpe',
#  'rolling_sortino',
#  'rolling_volatility',
#  'ror',
#  'safe_concat',
#  'serenity_index',
#  'sharpe',
#  'skew',
#  'smart_sharpe',
#  'smart_sortino',
#  'sortino',
#  'tail_ratio',
#  'to_drawdown_series',
#  'treynor_ratio',
#  'ulcer_index',
#  'ulcer_performance_index',
#  'upi',
#  'validate_input',
#  'value_at_risk',
#  'var',
#  'volatility',
#  'warn',
#  'win_loss_ratio',
#  'win_rate',
#  'worst']

# %%
[f for f in dir(qs.plots) if f[0] != '_']
# Out:
# ['daily_returns',
#  'distribution',
#  'drawdown',
#  'drawdowns_periods',
#  'earnings',
#  'histogram',
#  'log_returns',
#  'monthly_heatmap',
#  'monthly_returns',
#  'plotly',
#  'returns',
#  'rolling_beta',
#  'rolling_sharpe',
#  'rolling_sortino',
#  'rolling_volatility',
#  'safe_resample',
#  'snapshot',
#  'to_plotly',
#  'warnings',
#  'yearly_returns']

# %%
qs.plots.earnings(stock)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.

# %%
qs.reports.full(stock, "XLI")
# Out:
# [Performance Metrics]
#
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               1998-12-23   1998-12-23
# End Period                 2025-12-19   2025-12-19
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          973.25%      5,287.88%
# CAGR﹪                     9.21%        15.95%
#
# Sharpe                     0.52         0.62
# Prob. Sharpe Ratio         99.66%       99.93%
# Smart Sharpe               0.52         0.62
# Sortino                    0.74         0.9
# Smart Sortino              0.74         0.9
# Sortino/√2                 0.52         0.64
# Smart Sortino/√2           0.52         0.64
# Omega                      1.12         1.12
#
# Max Drawdown               -62.26%      -73.43%
# Max DD Date                2009-03-09   2009-03-02
# Max DD Period Start        2007-10-10   2007-07-20
# Max DD Period End          2011-04-28   2010-09-23
# Longest DD Days            1450         1538
# Volatility (ann.)          21.13%       32.47%
# R^2                        0.54         0.54
# Information Ratio          0.03         0.03
# Calmar                     0.15         0.22
# Skew                       -0.14        0.05
# Kurtosis                   7.86         4.55
#
# Expected Daily %           0.03%        0.06%
# Expected Monthly %         0.73%        1.23%
# Expected Yearly %          8.85%        15.3%
# Kelly Criterion            5.22%        3.65%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -2.15%       -3.28%
# Expected Shortfall (cVaR)  -4.36%       -4.36%
#
# Max Consecutive Wins       11           10
# Max Consecutive Losses     11           8
# Gain/Pain Ratio            0.1          0.12
# Gain/Pain (1M)             0.58         0.6
#
# Payoff Ratio               0.94         1.01
# Profit Factor              1.1          1.12
# Common Sense Ratio         1.06         1.17
# CPC Index                  0.56         0.58
# Tail Ratio                 0.96         1.05
# Outlier Win Ratio          5.23         3.13
# Outlier Loss Ratio         4.77         3.22
#
# MTD                        1.41%        0.08%
# 3M                         2.46%        23.75%
# 6M                         10.39%       61.2%
# YTD                        19.51%       61.24%
# 1Y                         19.49%       60.74%
# 3Y (ann.)                  18.3%        35.04%
# 5Y (ann.)                  13.81%       27.16%
# 10Y (ann.)                 13.65%       27.51%
# All-time (ann.)            9.21%        15.95%
#
# Best Day                   12.65%       14.72%
# Worst Day                  -11.34%      -14.52%
# Best Month                 18.07%       40.82%
# Worst Month                -18.63%      -35.26%
# Best Year                  40.55%       86.14%
# Worst Year                 -38.73%      -36.8%
#
# Avg. Drawdown              -3.21%       -5.3%
# Avg. Drawdown Days         41           60
# Recovery Factor            4.78         7.36
# Ulcer Index                0.15         0.21
# Serenity Index             0.54         1.06
#
# Avg. Up Month              4.68%        8.31%
# Avg. Down Month            -4.53%       -7.67%
# Win Days %                 53.96%       51.58%
# Win Month %                60.92%       57.23%
# Win Quarter %              63.3%        61.47%
# Win Year %                 75.0%        82.14%
#
# Beta                       -            1.13
# Alpha                      -            0.08
# Correlation                -            73.31%
# Treynor Ratio              -            4694.16%
#
#
#
# [Worst 5 Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2007-07-20  2009-03-02  2010-09-23    1162          -73.43              -69.51
#  2  1999-04-30  2000-10-18  2003-07-15    1538          -52.31              -49.01
#  3  2014-07-17  2016-01-25  2017-04-24    1013          -44.63              -42.50
#  4  2018-01-23  2020-03-23  2020-10-09     991          -43.36              -37.91
#  5  2011-05-02  2011-10-03  2012-02-02     277          -38.61              -35.75
#
#
#
# [Strategy Visualization]
# via Matplotlib
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
